# %%
from generator import Generator
from discriminator import Discriminator
from torch import nn
import torch

# %%
# initialize some parameters
criterion = nn.BCEWithLogitsLoss()
n_epochs = 200
z_dim = 64
display_step = 500
batch_size = 128
lr = 0.00001
device = 'cpu'

# %%
# load MNIST dataset as tensors

# %%
# initialize GAN
gen = Generator(z_dim).to(device)
gen_opt = torch.optim.Adam(gen.parameters(), lr = lr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e7e4cade6bb0> in <module>
#       1 # initialize GAN
# ----> 2 gen = Generator(z_dim).to(device)
#       3 gen_opt = torch.optim.Adam(gen.parameters(), lr = lr)
#
# ~/Documents/GitHub/intro_GANs/First GAN/generator.py in __init__(self, z_dim, im_dim, hidden_dim)
#      24         :param hidden_dim:
#      25         """
# ---> 26         self.gen = nn.Sequential(
#      27             get_generator_block(z_dim, hidden_dim),
#      28             get_generator_block(hidden_dim * 2, hidden_dim * 4),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in __setattr__(self, name, value)
#     798             if isinstance(value, Module):
#     799                 if modules is None:
# --> 800                     raise AttributeError(
#     801                         "cannot assign module before Module.__init__() call")
#     802                 remove_from(self.__dict__, self._parameters, self._buffers, self._non_persistent_buffers_set)
#
# AttributeError: cannot assign module before Module.__init__() call
