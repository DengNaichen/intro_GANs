# %%
import torch

# %%
a = torch.randn(2,2)
b = torch.ones_like(a)
print (a)
print (b)
# Out:
# tensor([[ 0.6929, -0.1867],
#         [ 0.9191,  0.5472]])
# tensor([[1., 1.],
#         [1., 1.]])

# %%
from torch import nn
loss = nn.BCEWithLogitsLoss()
input_tensor = torch.randn(3, requires_grad=True)
target = torch.ones(3)
print (input_tensor)
print (target)
output = loss (input_tensor, target)
print (output)
# Out:
# tensor([-0.0988,  0.0621,  0.4736], requires_grad=True)
# tensor([1., 1., 1.])
# tensor(0.6302, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)

# %%
def sigmoid(output_tensor):
    return 1/(1 + torch.exp(-output_tensor))

def bce_loss(output_tensor, target_tensor, sigmoid):
    return - torch.mean(target_tensor * torch.log(sigmoid(output_tensor)) + (1 - target) * torch.log(1 - sigmoid(output_tensor)))

# %%
c = bce_loss(input_tensor, target, sigmoid)

# %%
print (c)
# Out:
# tensor(0.6302, grad_fn=<NegBackward>)

# %%
from discriminator import Discriminator
from generator import Generator

# %%
gen = Generator.get_gen()
# print (gen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5a8dac79a34f> in <module>
# ----> 1 gen = Generator.get_gen(self)
#       2 # print (gen)
#
# NameError: name 'self' is not defined

# %%
import torch
disc = Discriminator().get_disc()
image = torch.randn(786, 1)

# %%
print (image)
a = disc(image)
# Out:
# tensor([[[ 7.7644e-01,  2.1237e-01, -3.7085e-01, -8.1482e-01, -6.9187e-01,
#            8.7359e-01,  1.0941e+00, -4.0486e-01,  2.1966e-01,  1.1045e+00,
#            5.5863e-02, -1.2743e+00,  5.6885e-01, -1.7292e+00, -8.9098e-01,
#           -9.2356e-01,  1.1185e+00,  8.0008e-01, -8.0741e-01, -2.2348e-01,
#            5.1019e-02,  1.5897e+00, -1.1365e+00,  1.6701e-01,  1.8939e-01,
#            5.5635e-01, -1.4612e+00, -2.0583e+00],
#          [ 2.5513e-01, -1.3597e+00, -9.0073e-01,  9.6262e-01, -1.4326e+00,
#           -1.3951e+00,  1.5779e+00, -3.0001e+00, -5.5201e-02, -2.6008e-01,
#            6.3856e-01,  2.4147e+00,  8.6720e-01, -2.9917e+00,  5.7554e-01,
#           -1.0039e+00, -2.9106e-01,  1.4902e+00, -1.0485e+00, -1.2443e+00,
#            4.7789e-01,  1.4671e+00, -2.1509e+00,  6.0897e-01, -8.8210e-01,
#           -5.2745e-01,  9.2145e-01,  5.9394e-02],
#          [ 2.3701e+00,  1.7539e+00,  4.0466e-01, -1.2501e+00, -3.3755e-01,
#           -3.0706e+00, -8.3534e-01, -6.5925e-01,  4.4437e-01,  4.4297e-01,
#            4.6797e-01,  1.9740e-01,  8.5916e-02, -1.5104e+00, -2.9489e-01,
#           -1.0666e+00, -8.3809e-01,  6.8922e-01,  2.6181e-01, -5.5905e-02,
#            1.4251e+00,  1.1334e-01,  2.3212e-01,  6.8951e-03,  1.3159e+00,
#           -4.9349e-01,  4.8810e-01,  8.3114e-01],
#          [ 7.1285e-01, -2.0544e-01,  1.7882e+00, -2.2218e+00, -6.5736e-01,
#            3.4351e-01,  1.7487e+00, -1.7315e-01,  1.3407e+00, -1.2142e+00,
#           -3.3559e-01, -1.3165e+00,  1.2939e+00,  8.5183e-02, -1.7422e+00,
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-0eadfef5e695> in <module>
#       1 print (image)
# ----> 2 a = disc(image)
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/GitHub/intro_GANs/first_gan/discriminator.py in forward(self, image)
#      32
#      33     def forward(self, image):
# ---> 34         return self.disc(image)
#      35
#      36     def get_disc(self):
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/opt/anaconda3/envs/nn/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# RuntimeError: size mismatch, m1: [28 x 28], m2: [784 x 512] at /tmp/pip-req-build-9oilk29k/aten/src/TH/generic/THTensorMath.cpp:197

# %%
from torchsummary import summary

# %%
print (disc)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (1): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (2): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (3): Linear(in_features=128, out_features=1, bias=True)
# )
